# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
tickers = ['^GSPC','^IXIC','^GDAXI']
ind_data = pd.DataFrame()
for t in tickers:
    ind_data[t] = wb.DataReader(t, data_source ='yahoo', start='1997-1-1')['Adj Close']

# %%
ind_data.head()
# Out:
#                  ^GSPC        ^IXIC       ^GDAXI
# Date
# 1996-12-31  740.739990  1291.030029          NaN
# 1997-01-02  737.010010  1280.699951  2820.810059
# 1997-01-03  748.030029  1310.680054  2863.260010
# 1997-01-06  747.650024  1316.400024  2890.199951
# 1997-01-07  753.229980  1327.729980  2876.340088

# %%
ind_data.tail()
# Out:
#                   ^GSPC        ^IXIC        ^GDAXI
# Date
# 2020-03-23  2237.399902  6860.669922   8741.150391
# 2020-03-24  2447.330078  7417.859863   9700.570312
# 2020-03-25  2475.560059  7384.299805   9874.259766
# 2020-03-26  2630.070068  7797.540039  10000.959961
# 2020-03-27  2541.469971  7502.379883   9632.519531

# %%
((ind_data / ind_data.iloc[0]) * 100 ).plot(figsize=(15,6)); # Normalizing so that all prices start from 100 and it is a fair competition
plt.show()

# %%
ind_returns = (ind_data / ind_data.shift(1)) - 1
ind_returns.tail()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI
# Date
# 2020-03-23 -0.029294 -0.002740 -0.021033
# 2020-03-24  0.093828  0.081215  0.109759
# 2020-03-25  0.011535 -0.004524  0.017905
# 2020-03-26  0.062414  0.055962  0.012831
# 2020-03-27 -0.033687 -0.037853 -0.036841

# %%
annual_ind_returns = ind_returns.mean() * 250
annual_ind_returns
# Out:
# ^GSPC     0.071893
# ^IXIC     0.106939
# ^GDAXI    0.065482
# dtype: float64

# %%
tickers = ['PG','^GSPC','^DJI']
data_2 = pd.DataFrame()
for t in tickers : 
    data_2[t] = wb.DataReader(t, data_source = 'yahoo', start = '2007-01-01')['Adj Close']

# %%
data_2.head()
# Out:
#                    PG        ^GSPC          ^DJI
# Date
# 2007-01-03  43.435280  1416.599976  12474.519531
# 2007-01-04  43.105507  1418.339966  12480.690430
# 2007-01-05  42.735352  1409.709961  12398.009766
# 2007-01-08  42.829563  1412.839966  12423.490234
# 2007-01-09  42.721889  1412.109985  12416.599609

# %%
data_2.tail()
# Out:
#                     PG        ^GSPC          ^DJI
# Date
# 2020-03-23   97.699997  2237.399902  18591.929688
# 2020-03-24  103.269997  2447.330078  20704.910156
# 2020-03-25  100.919998  2475.560059  21200.550781
# 2020-03-26  107.379997  2630.070068  22552.169922
# 2020-03-27  110.169998  2541.469971  21636.779297

# %%
((data_2/data_2.iloc[0]) * 100).plot(figsize = (15,6)); # Normalizing the data_2 as we did above for eariler data above
plt.show()
